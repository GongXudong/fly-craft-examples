# %%
from pathlib import Path
import numpy as np
import pandas as pd
from flycraft.utils.geometry_utils import angle_of_2_velocity
PROJECT_ROOT_DIR = Path().absolute().parent.parent.parent
PROJECT_ROOT_DIR
# Out:
# PosixPath('/home/sen/pythonprojects/fly-craft-examples')

# %%
def process_one_file(file_path: Path):
    df = pd.read_csv(file_path)
    df["v_error"] = np.abs(df["v"] - df["achieved v"])
    #df["angle_error"] = df.apply(lambda row: np.abs(angle_of_2_velocity(row["v"], row["mu"], row["chi"], row["achieved v"], row["achieved mu"], row["achieved chi"])), axis=1)
    success_rate = len(df[df["termination"] == "reach target"])/len(df)
    df_timeout = df[(df["termination"] == "timeout")]
    len_of_timeout = len(df_timeout)
    average_angle_error =  sum(df_timeout["error"]) / len_of_timeout
    average_v_error = sum(df_timeout["v_error"]) / len_of_timeout
    return df_timeout,len_of_timeout,average_angle_error,average_v_error,success_rate

# %%
files = [
    "logs/cache/LadderRL/eval_error/b_2_one_stage_skip_5_5e6steps_hard_1.csv", 
    "logs/cache/LadderRL/eval_error/b_2_one_stage_skip_5_5e6steps_hard_2.csv", 
    "logs/cache/LadderRL/eval_error/b_2_one_stage_skip_5_5e6steps_hard_3.csv", 
    "logs/cache/LadderRL/eval_error/b_2_one_stage_skip_5_5e6steps_hard_4.csv", 
    "logs/cache/LadderRL/eval_error/b_2_one_stage_skip_5_5e6steps_hard_5.csv", 
]

outcome = []
for index,file in enumerate(files):
    df_timeout,lens,angle_error,v_error,success_rate = process_one_file(PROJECT_ROOT_DIR / file )
    current_outcome = {
        "seed": index+1,
        "len_of_timeout": lens,
        "angle": angle_error,
        "v":v_error,
        "success_rate":success_rate,
    }
    outcome.append(current_outcome)
print(outcome)

# 计算平均值
avg_length = sum(item['len_of_timeout'] for item in outcome) / len(outcome)
avg_angle = sum(item['angle'] for item in outcome) / len(outcome)
avg_velocity = sum(item['v'] for item in outcome) / len(outcome)
avg_successrate = sum(item['success_rate'] for item in outcome) / len(outcome)
print(f"Average length: {avg_length:.2f}")
print(f"Average angle: {avg_angle:.2f}")
print(f"Average velocity: {avg_velocity:.2f}")
print(f"Average successrate: {avg_successrate:.2f}")
# Out:
# [{'seed': 1, 'len_of_timeout': 7058, 'angle': 32.613958880071316, 'v': 15.08698110829009, 'success_rate': 0.2874}, {'seed': 2, 'len_of_timeout': 7410, 'angle': 35.60372361937792, 'v': 14.419363116098655, 'success_rate': 0.2548}, {'seed': 3, 'len_of_timeout': 8102, 'angle': 34.445481576314855, 'v': 11.775064508364215, 'success_rate': 0.1853}, {'seed': 4, 'len_of_timeout': 7331, 'angle': 33.93366729857111, 'v': 10.217779727827763, 'success_rate': 0.2513}, {'seed': 5, 'len_of_timeout': 8246, 'angle': 33.530820948225056, 'v': 13.13899240323808, 'success_rate': 0.1671}]
# Average length: 7629.40
# Average angle: 34.03
# Average velocity: 12.93
# Average successrate: 0.23

# %%
files = [
    "logs/cache/LadderRL/eval_error/b_05_one_stage_skip_5_5e6steps_hard_1.csv", 
    "logs/cache/LadderRL/eval_error/b_05_one_stage_skip_5_5e6steps_hard_2.csv", 
    "logs/cache/LadderRL/eval_error/b_05_one_stage_skip_5_5e6steps_hard_3.csv", 
    "logs/cache/LadderRL/eval_error/b_05_one_stage_skip_5_5e6steps_hard_4.csv", 
    "logs/cache/LadderRL/eval_error/b_05_one_stage_skip_5_5e6steps_hard_5.csv", 
]


outcome = []
for index,file in enumerate(files):
    df_timeout,lens,angle_error,v_error,success_rate = process_one_file(PROJECT_ROOT_DIR / file )
    current_outcome = {
        "seed": index+1,
        "len_of_timeout": lens,
        "angle": angle_error,
        "v":v_error,
        "success_rate":success_rate,
    }
    outcome.append(current_outcome)
print(outcome)

# 计算平均值
avg_length = sum(item['len_of_timeout'] for item in outcome) / len(outcome)
avg_angle = sum(item['angle'] for item in outcome) / len(outcome)
avg_velocity = sum(item['v'] for item in outcome) / len(outcome)
avg_successrate = sum(item['success_rate'] for item in outcome) / len(outcome)
print(f"Average length: {avg_length:.2f}")
print(f"Average angle: {avg_angle:.2f}")
print(f"Average velocity: {avg_velocity:.2f}")
print(f"Average successrate: {avg_successrate:.2f}")
# Out:
# [{'seed': 1, 'len_of_timeout': 988, 'angle': 31.885686129161883, 'v': 13.09664736640692, 'success_rate': 0.6707}, {'seed': 2, 'len_of_timeout': 782, 'angle': 45.274896653951, 'v': 12.990872161859654, 'success_rate': 0.7187}, {'seed': 3, 'len_of_timeout': 905, 'angle': 57.63737035333369, 'v': 10.85213817833375, 'success_rate': 0.7631}, {'seed': 4, 'len_of_timeout': 3743, 'angle': 47.81822441844351, 'v': 14.904776505878443, 'success_rate': 0.4401}, {'seed': 5, 'len_of_timeout': 1753, 'angle': 39.79794966420413, 'v': 15.545735337183642, 'success_rate': 0.6634}]
# Average length: 1634.20
# Average angle: 44.48
# Average velocity: 13.48
# Average successrate: 0.65

# %% [markdown]
# ****

# %% [markdown]
# # hard skip 3 5e6
# ### b = 2

# %%
files = [
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_2_skip_3_hard_5e6steps_hard_1.csv", 
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_2_skip_3_hard_5e6steps_hard_2.csv", 
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_2_skip_3_hard_5e6steps_hard_3.csv", 
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_2_skip_3_hard_5e6steps_hard_4.csv", 
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_2_skip_3_hard_5e6steps_hard_5.csv", 
]


outcome = []
for index,file in enumerate(files):
    df_timeout,lens,angle_error,v_error,success_rate = process_one_file(PROJECT_ROOT_DIR / file )
    current_outcome = {
        "seed": index+1,
        "len_of_timeout": lens,
        "angle": angle_error,
        "v":v_error,
        "success_rate":success_rate,
    }
    outcome.append(current_outcome)
print(outcome)

# 计算平均值
avg_length = sum(item['len_of_timeout'] for item in outcome) / len(outcome)
avg_angle = sum(item['angle'] for item in outcome) / len(outcome)
avg_velocity = sum(item['v'] for item in outcome) / len(outcome)
avg_successrate = sum(item['success_rate'] for item in outcome) / len(outcome)
print(f"Average length: {avg_length:.2f}")
print(f"Average angle: {avg_angle:.2f}")
print(f"Average velocity: {avg_velocity:.2f}")
print(f"Average successrate: {avg_successrate:.2f}")
# Out:
# [{'seed': 1, 'len_of_timeout': 9042, 'angle': 40.98999283789619, 'v': 13.898602249384906, 'success_rate': 0.0803}, {'seed': 2, 'len_of_timeout': 8487, 'angle': 38.55463415481116, 'v': 19.134182234297104, 'success_rate': 0.1466}, {'seed': 3, 'len_of_timeout': 9089, 'angle': 43.772339001622214, 'v': 13.492863701266472, 'success_rate': 0.081}, {'seed': 4, 'len_of_timeout': 9046, 'angle': 39.608231686222084, 'v': 15.966064231410751, 'success_rate': 0.0882}, {'seed': 5, 'len_of_timeout': 8707, 'angle': 50.890959329039916, 'v': 25.009240233648462, 'success_rate': 0.0531}]
# Average length: 8874.20
# Average angle: 42.76
# Average velocity: 17.50
# Average successrate: 0.09

# %% [markdown]
# # hard skip 3 5e6
# ### b = 1

# %%
files = [
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_1_skip_3_hard_5e6steps_hard_1.csv", 
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_1_skip_3_hard_5e6steps_hard_2.csv", 
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_1_skip_3_hard_5e6steps_hard_3.csv", 
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_1_skip_3_hard_5e6steps_hard_4.csv", 
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_1_skip_3_hard_5e6steps_hard_5.csv", 
]


outcome = []
for index,file in enumerate(files):
    df_timeout,lens,angle_error,v_error,success_rate = process_one_file(PROJECT_ROOT_DIR / file )
    current_outcome = {
        "seed": index+1,
        "len_of_timeout": lens,
        "angle": angle_error,
        "v":v_error,
        "success_rate":success_rate,
    }
    outcome.append(current_outcome)
print(outcome)

# 计算平均值
avg_length = sum(item['len_of_timeout'] for item in outcome) / len(outcome)
avg_angle = sum(item['angle'] for item in outcome) / len(outcome)
avg_velocity = sum(item['v'] for item in outcome) / len(outcome)
avg_successrate = sum(item['success_rate'] for item in outcome) / len(outcome)
print(f"Average length: {avg_length:.2f}")
print(f"Average angle: {avg_angle:.2f}")
print(f"Average velocity: {avg_velocity:.2f}")
print(f"Average successrate: {avg_successrate:.2f}")
# Out:
# [{'seed': 1, 'len_of_timeout': 6611, 'angle': 39.67642158293903, 'v': 14.991661714371519, 'success_rate': 0.2924}, {'seed': 2, 'len_of_timeout': 7209, 'angle': 50.912451764178776, 'v': 16.810022058795955, 'success_rate': 0.1755}, {'seed': 3, 'len_of_timeout': 6362, 'angle': 38.28227100022405, 'v': 10.549643519428438, 'success_rate': 0.3409}, {'seed': 4, 'len_of_timeout': 8082, 'angle': 48.509727385989876, 'v': 17.06774258366994, 'success_rate': 0.1659}, {'seed': 5, 'len_of_timeout': 6910, 'angle': 36.21514534984422, 'v': 13.362230034163357, 'success_rate': 0.2835}]
# Average length: 7034.80
# Average angle: 42.72
# Average velocity: 14.56
# Average successrate: 0.25

# %% [markdown]
# # hard skip 3 5e6
# ### b = 0.5

# %%
files = [
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_05_skip_3_hard_5e6steps_hard_1.csv", 
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_05_skip_3_hard_5e6steps_hard_2.csv", 
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_05_skip_3_hard_5e6steps_hard_3.csv", 
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_05_skip_3_hard_5e6steps_hard_4.csv", 
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_05_skip_3_hard_5e6steps_hard_5.csv", 
]


outcome = []
for index,file in enumerate(files):
    df_timeout,lens,angle_error,v_error,success_rate = process_one_file(PROJECT_ROOT_DIR / file )
    current_outcome = {
        "seed": index+1,
        "len_of_timeout": lens,
        "angle": angle_error,
        "v":v_error,
        "success_rate":success_rate,
    }
    outcome.append(current_outcome)
print(outcome)

# 计算平均值
avg_length = sum(item['len_of_timeout'] for item in outcome) / len(outcome)
avg_angle = sum(item['angle'] for item in outcome) / len(outcome)
avg_velocity = sum(item['v'] for item in outcome) / len(outcome)
avg_successrate = sum(item['success_rate'] for item in outcome) / len(outcome)
print(f"Average length: {avg_length:.2f}")
print(f"Average angle: {avg_angle:.2f}")
print(f"Average velocity: {avg_velocity:.2f}")
print(f"Average successrate: {avg_successrate:.2f}")
# Out:
# [{'seed': 1, 'len_of_timeout': 5533, 'angle': 46.96332372172846, 'v': 20.35548515149975, 'success_rate': 0.3127}, {'seed': 2, 'len_of_timeout': 6234, 'angle': 46.435307820262175, 'v': 23.957717082370376, 'success_rate': 0.2767}, {'seed': 3, 'len_of_timeout': 6832, 'angle': 48.99002083698723, 'v': 36.26096869395464, 'success_rate': 0.1318}, {'seed': 4, 'len_of_timeout': 6867, 'angle': 47.91885701004559, 'v': 26.09683649601844, 'success_rate': 0.1784}, {'seed': 5, 'len_of_timeout': 6775, 'angle': 45.35661248632057, 'v': 20.739140689379738, 'success_rate': 0.24}]
# Average length: 6448.20
# Average angle: 47.13
# Average velocity: 25.48
# Average successrate: 0.23

# %% [markdown]
# # hard skip 3 5e6
# ### b = 0.25

# %%
files = [
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_025_skip_3_hard_5e6steps_hard_1.csv", 
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_025_skip_3_hard_5e6steps_hard_2.csv", 
    #"logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_025_skip_3_hard_5e6steps_hard_3.csv", 
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_025_skip_3_hard_5e6steps_hard_4.csv", 
    "logs/cache/LadderRL/eval_error/hard_skip3_5e6/b_025_skip_3_hard_5e6steps_hard_5.csv", 
]


outcome = []
for index,file in enumerate(files):
    df_timeout,lens,angle_error,v_error,success_rate = process_one_file(PROJECT_ROOT_DIR / file )
    current_outcome = {
        "seed": index+1,
        "len_of_timeout": lens,
        "angle": angle_error,
        "v":v_error,
        "success_rate":success_rate,
    }
    outcome.append(current_outcome)
print(outcome)

# 计算平均值
avg_length = sum(item['len_of_timeout'] for item in outcome) / len(outcome)
avg_angle = sum(item['angle'] for item in outcome) / len(outcome)
avg_velocity = sum(item['v'] for item in outcome) / len(outcome)
avg_successrate = sum(item['success_rate'] for item in outcome) / len(outcome)
print(f"Average length: {avg_length:.2f}")
print(f"Average angle: {avg_angle:.2f}")
print(f"Average velocity: {avg_velocity:.2f}")
print(f"Average successrate: {avg_successrate:.2f}")
# Out:
# [{'seed': 1, 'len_of_timeout': 372, 'angle': 24.15269934047303, 'v': 27.30887627744744, 'success_rate': 0.4186}, {'seed': 2, 'len_of_timeout': 366, 'angle': 25.0837669844015, 'v': 13.448994444078279, 'success_rate': 0.3942}, {'seed': 3, 'len_of_timeout': 146, 'angle': 29.903888355902406, 'v': 48.5406709862229, 'success_rate': 0.4449}, {'seed': 4, 'len_of_timeout': 372, 'angle': 19.71356503114082, 'v': 12.165595353228396, 'success_rate': 0.5494}]
# Average length: 314.00
# Average angle: 24.71
# Average velocity: 25.37
# Average successrate: 0.45

# %%
# hard skip3 b = 2 
# [{'seed': 1, 'len_of_timeout': 9042, 'angle': 40.98999283789619, 'v': 13.898602249384906, 'success_rate': 0.0803}, {'seed': 2, 'len_of_timeout': 8487, 'angle': 38.55463415481116, 'v': 19.134182234297104, 'success_rate': 0.1466}, {'seed': 3, 'len_of_timeout': 9089, 'angle': 43.772339001622214, 'v': 13.492863701266472, 'success_rate': 0.081}, {'seed': 4, 'len_of_timeout': 9046, 'angle': 39.608231686222084, 'v': 15.966064231410751, 'success_rate': 0.0882}, {'seed': 5, 'len_of_timeout': 8707, 'angle': 50.890959329039916, 'v': 25.009240233648462, 'success_rate': 0.0531}]
# Average length: 8874.20
# Average angle: 42.76
# Average velocity: 17.50
# Average successrate: 0.09



# hard skip3 b = 1
# [{'seed': 1, 'len_of_timeout': 6611, 'angle': 39.67642158293903, 'v': 14.991661714371519, 'success_rate': 0.2924}, {'seed': 2, 'len_of_timeout': 7209, 'angle': 50.912451764178776, 'v': 16.810022058795955, 'success_rate': 0.1755}, {'seed': 3, 'len_of_timeout': 6362, 'angle': 38.28227100022405, 'v': 10.549643519428438, 'success_rate': 0.3409}, {'seed': 4, 'len_of_timeout': 8082, 'angle': 48.509727385989876, 'v': 17.06774258366994, 'success_rate': 0.1659}, {'seed': 5, 'len_of_timeout': 6910, 'angle': 36.21514534984422, 'v': 13.362230034163357, 'success_rate': 0.2835}]
# Average length: 7034.80
# Average angle: 42.72
# Average velocity: 14.56
# Average successrate: 0.25


# hard skip3 b = 0.5
# [{'seed': 1, 'len_of_timeout': 5533, 'angle': 46.96332372172846, 'v': 20.35548515149975, 'success_rate': 0.3127}, {'seed': 2, 'len_of_timeout': 6234, 'angle': 46.435307820262175, 'v': 23.957717082370376, 'success_rate': 0.2767}, {'seed': 3, 'len_of_timeout': 6832, 'angle': 48.99002083698723, 'v': 36.26096869395464, 'success_rate': 0.1318}, {'seed': 4, 'len_of_timeout': 6867, 'angle': 47.91885701004559, 'v': 26.09683649601844, 'success_rate': 0.1784}, {'seed': 5, 'len_of_timeout': 6775, 'angle': 45.35661248632057, 'v': 20.739140689379738, 'success_rate': 0.24}]
# Average length: 6448.20
# Average angle: 47.13
# Average velocity: 25.48
# Average successrate: 0.23


# hard skip3 b = 0.25
# [{'seed': 1, 'len_of_timeout': 372, 'angle': 24.15269934047303, 'v': 27.30887627744744, 'success_rate': 0.4186}, {'seed': 2, 'len_of_timeout': 366, 'angle': 25.0837669844015, 'v': 13.448994444078279, 'success_rate': 0.3942}, {'seed': 3, 'len_of_timeout': 146, 'angle': 29.903888355902406, 'v': 48.5406709862229, 'success_rate': 0.4449}, {'seed': 4, 'len_of_timeout': 372, 'angle': 19.71356503114082, 'v': 12.165595353228396, 'success_rate': 0.5494}]
# Average length: 314.00
# Average angle: 24.71
# Average velocity: 25.37
# Average successrate: 0.45
