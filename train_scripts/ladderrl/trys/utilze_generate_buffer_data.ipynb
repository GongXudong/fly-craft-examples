# %%
import gymnasium as gym
import numpy as np
from pathlib import Path
import os
import sys
import torch as th
import argparse

from stable_baselines3 import HerReplayBuffer, SAC
from stable_baselines3.common.buffers import DictReplayBuffer
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.logger import configure, Logger
from stable_baselines3.common.callbacks import CheckpointCallback, EveryNTimesteps
import flycraft
from flycraft.utils.load_config import load_config

import sys
from pathlib import Path
import os
current_dir = os.getcwd()
print(current_dir)
PROJECT_ROOT_DIR = Path(current_dir).parent.parent.parent
if str(PROJECT_ROOT_DIR.absolute()) not in sys.path:
    sys.path.append(str(PROJECT_ROOT_DIR.absolute()))

from utils_my.sb3.my_eval_callback import MyEvalCallback
from utils_my.sb3.my_evaluate_policy import evaluate_policy_with_success_rate
from train_scripts.D2D.utils.get_vec_env import get_vec_env
from train_scripts.D2D.utils.load_data_from_csv import load_random_trajectories_from_csv_files,load_random_transitions_from_csv_files
from train_scripts.D2D.utils.InfoDictReplayBuffer import InfoDictReplayBuffer
from utils_my.sb3.my_wrappers import ScaledObservationWrapper, ScaledActionWrapper
import pathlib
import warnings
warnings.filterwarnings("ignore")  # 过滤Gymnasium的UserWarning
gym.register_envs(flycraft)

from stable_baselines3.common.logger import configure




train_config = load_config(PROJECT_ROOT_DIR/ "configs/train/D2D/F2F/medium/b_1/two_stage_skip_3_skip_1/2e6/sac_config_10hz_128_128_1.json")



NET_ARCH = train_config["rl_common"]["net_arch"]
GAMMA = train_config["rl_common"].get("gamma", 0.995)
BUFFER_SIZE = train_config["rl_common"].get("buffer_size", 1e6)
BATCH_SIZE = train_config["rl_common"].get("batch_size", 1024)
RL_TRAIN_PROCESS_NUM = train_config["rl_common"].get("rollout_process_num", 32)
RL_EVALUATE_PROCESS_NUM = train_config["rl_common"].get("evaluate_process_num", 32)
CALLBACK_PROCESS_NUM = train_config["rl_common"].get("callback_process_num", 32)
# GRADIENT_STEPS = train_config["rl_common"].get("gradient_steps", 2)
EVAL_FREQ = train_config["rl_common"].get("eval_freq", 1000)
N_EVAL_EPISODES = train_config["rl_common"].get("n_eval_episodes", CALLBACK_PROCESS_NUM*10)
USE_HER = train_config["rl_common"].get("use_her", False)
learning_rate = 3e-4

env_config_in_train = {
"num_process": 32,
"seed": 183,
"config_file": str(PROJECT_ROOT_DIR / "configs" / "env" / "D2D/env_config_for_sac_medium_b_1.json"),
# "custom_config": {"debug_mode": True, "flag_str": "Callback"}

}





vec_env = get_vec_env(
            **env_config_in_train
        )








sac_algo = SAC(
    "MultiInputPolicy",
    vec_env,
    seed=245,
    replay_buffer_class=HerReplayBuffer if USE_HER else InfoDictReplayBuffer,
    replay_buffer_kwargs=dict(
        n_sampled_goal=4,
        goal_selection_strategy="future",
    ) if USE_HER else None,
    verbose=1,
    buffer_size=int(BUFFER_SIZE),
    learning_starts=int(0),
    gradient_steps=int(20000),
    learning_rate=learning_rate,
    gamma=GAMMA,
    batch_size=int(BATCH_SIZE),
    policy_kwargs=dict(
        net_arch=NET_ARCH,
        activation_fn=th.nn.Tanh
    ),
)
# 设置 logger（保存路径 / 输出模式等）
sac_algo.set_logger(configure(folder="/home/sen/pythonprojects/fly-craft-examples/checkpoints/D2D/F2F/medium/b_1/skip_3_1_test_warmup", format_strings=["stdout", "csv"]))
def eval(policy_list):
    
    average_reward = 0.0
    average_std = 0.0
    average_successrate = 0.0 
    for index, policy in enumerate(policy_list):
        sac = SAC.load(policy)
        eval_reward, std_reward, eval_success_rate = evaluate_policy_with_success_rate(sac.policy, vec_env, 1000)
        print(f"seed{index+1}  ：",f"mean_reward={eval_reward:.2f} +/- {std_reward}")
        average_reward += eval_reward
        average_std += std_reward
        average_successrate +=eval_success_rate
    return average_reward/len(policy_list),average_std/len(policy_list), average_successrate/len(policy_list)


sac_algo.load_replay_buffer("/home/sen/pythonprojects/fly-craft-examples/checkpoints/D2D/F2F/medium/b_1/skip_3/sac_128_128_b_1_1e6steps_skip_3_seed_1_singleRL/replay_buffer")

sac_algo.train(batch_size=1024,gradient_steps=20000)

sac_algo.save(str(PROJECT_ROOT_DIR / "checkpoints/D2D/F2F/medium/b_1/skip_3_1_test_warmup"/ "final_model"))
sac_algo.save_replay_buffer(str(PROJECT_ROOT_DIR / "checkpoints/D2D/F2F/medium/b_1/skip_3_1_test_warmup"  / "final_buffer"))

policy_list = ["/home/sen/pythonprojects/fly-craft-examples/checkpoints/D2D/F2F/medium/b_1/skip_3_1_test_warmup/final_model.zip"]

reward,std_reward,success_rate  = eval(policy_list)
print(f"mean_reward={reward:.2f} +/- {std_reward}", f"success_rate = {success_rate}")
# Out:
# /home/sen/pythonprojects/fly-craft-examples/train_scripts/D2D/trys
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 190 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 186 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 196 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 200 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 188 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.jsonload config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 193 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 209 Generator(PCG64) Generator(PCG64)
#
# 183 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 187 Generator(PCG64) Generator(PCG64)
# 203 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 202 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 205 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 191 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 192 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 213 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 206 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 184 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 214 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 208 Generator(PCG64) Generator(PCG64)
# 204 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 195 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 201 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 212 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 207 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 194 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 211 Generator(PCG64) Generator(PCG64)
# 185 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 197 Generator(PCG64) Generator(PCG64)
# 189 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 210 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 198 Generator(PCG64) Generator(PCG64)
# load config from: /home/sen/pythonprojects/fly-craft-examples/configs/env/D2D/env_config_for_sac_medium_b_1.json
# 199 Generator(PCG64) Generator(PCG64)
# Using cuda device
# Logging to /home/sen/pythonprojects/fly-craft-examples/checkpoints/D2D/F2F/medium/b_1/skip_3_1_test_warmup
# print, Train, timeout_termination。 steps: 399。target: (175.24, -10.89, 33.95)。achieved target: (37.26, -11.25, -92.88)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (225.86, 14.48, 11.90)。achieved target: (76.69, -39.08, -101.92)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (190.75, -1.88, -46.29)。achieved target: (26.29, 4.74, -135.83)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (215.37, 13.79, -54.64)。achieved target: (31.96, -13.59, -47.87)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (244.91, 28.99, 52.38)。achieved target: (71.21, -42.15, -103.05)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (170.40, 9.32, -50.90)。achieved target: (23.60, -3.11, -47.71)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (206.26, 1.39, 36.75)。achieved target: (47.92, -24.31, -84.87)。expert steps: 0。print, Train, timeout_termination。 steps: 399。target:
。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (182.26, -25.73, -11.30)。achieved target: (40.15, 28.23, -95.80)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (150.21, -23.30, 24.01)。achieved target: (32.26, 1.09, -141.82)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (158.58, -27.31, 15.00)。achieved target: (31.76, 28.58, -121.62)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (160.74, -16.11, 8.67)。achieved target: (30.15, 7.03, -117.82)。expert steps: 0。print, Train, timeout_termination。 steps: 399。target: (152.59, -28.47, -23.08)。achieved target: (48.19, 47.96, -121.81)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (198.29, 2.02, -42.57)。achieved target: (31.76, -12.44, -143.11)。expert steps: 0。
#
# print, Train, timeout_termination。 steps: 399。target: (211.55, 14.76, -18.54)。achieved target: (47.31, -26.53, -107.46)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (200.79, -26.57, 54.23)。achieved target: (37.39, 0.96, -59.85)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (208.87, 0.99, 10.51)。achieved target: (40.75, -17.06, -97.45)。expert steps: 0。print, Train, timeout_termination。 steps: 399。target: (212.64, -13.21, 28.07)。achieved target: (38.49, -6.82, -57.28)。expert steps: 0。print, Train, timeout_termination。 steps: 399。target: (200.85, -6.61, -35.37)。achieved target: (28.00, 10.34, -121.07)。expert steps: 0。
#
#
# print, Train, timeout_termination。 steps: 399。target: (229.99, 12.52, 11.84)。achieved target: (52.69, -28.83, -91.36)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (183.56, -2.10, -7.45)。achieved target: (29.31, -7.38, -112.33)。expert steps: 0。print, Train, timeout_termination。 steps: 399。target: (240.61, -11.24, 49.54)。achieved target: (39.42, -7.84, -64.45)。expert steps: 0。
#
# print, Train, timeout_termination。 steps: 399。target: (168.16, 25.64, -23.10)。achieved target: (43.06, -1.90, -113.38)。expert steps: 0。print, Train, timeout_termination。 steps: 399。target: (211.86, 1.89, 58.82)。achieved target: (51.82, -27.55, -68.68)。expert steps: 0。
#
# print, Train, timeout_termination。 steps: 399。target: (228.33, 23.65, -44.41)。achieved target: (76.13, -34.40, -117.48)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (239.41, -22.88, 11.23)。achieved target: (33.82, 17.23, -85.09)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (218.79, 19.73, 13.82)。achieved target: (50.32, -5.20, -86.23)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (210.39, 6.15, -57.58)。achieved target: (24.33, 1.59, -52.49)。expert steps: 0。print, Train, timeout_termination。 steps: 399。target: (231.95, 6.39, 0.88)。achieved target: (58.59, -27.20, -116.10)。expert steps: 0。
#
# print, Train, timeout_termination。 steps: 399。target: (249.55, 8.68, 21.79)。achieved target: (45.05, -26.23, -81.05)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (217.30, -29.54, -27.98)。achieved target: (45.77, 35.94, -108.42)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (220.13, -28.21, -13.27)。achieved target: (35.78, 35.83, -118.31)。expert steps: 0。print, Train, timeout_termination。 steps: 399。target: (200.20, 5.85, -19.35)。achieved target: (39.66, -11.87, -117.35)。expert steps: 0。print, Train, timeout_termination。 steps: 399。target: (211.67, 16.75, 14.73)。achieved target: (64.26, -35.36, -118.54)。expert steps: 0。
#
#
# print, Train, timeout_termination。 steps: 399。target: (216.24, -8.79, -6.60)。achieved target: (33.30, -6.46, -120.07)。expert steps: 0。print, Train, timeout_termination。 steps: 399。target: (192.76, 25.50, 14.29)。achieved target: (75.69, -39.91, -125.12)。expert steps: 0。
#
# print, Train, timeout_termination。 steps: 399。target: (242.07, -27.82, 19.54)。achieved target: (35.37, 20.68, -84.59)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (194.72, -21.99, -12.91)。achieved target: (31.62, 26.98, -114.55)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (238.99, 18.98, -53.60)。achieved target: (55.58, -32.41, -135.91)。expert steps: 0。
# ...
#
# print, Train, timeout_termination。 steps: 399。target: (215.62, 10.95, 56.87)。achieved target: (46.58, -31.10, -72.88)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (166.72, -12.37, -13.72)。achieved target: (29.61, 6.43, -134.32)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (156.64, -27.08, 39.66)。achieved target: (33.14, 12.12, -108.92)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (158.97, -10.79, 12.13)。achieved target: (33.07, -5.70, -119.86)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (233.69, -7.52, -46.70)。achieved target: (26.42, 10.73, -134.73)。expert steps: 0。print, Train, timeout_termination。 steps: 399。target: (173.90, -14.19, 44.23)。achieved target: (38.74, -7.50, -57.72)。expert steps: 0。
#
# print, Train, timeout_termination。 steps: 399。target: (235.35, -23.85, 43.91)。achieved target: (37.81, 1.44, -62.77)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target:
。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (205.44, -4.33, -33.96)。achieved target: (30.34, 3.37, -119.72)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (181.92, -4.99, 0.22)。achieved target: (37.25, -6.62, -106.59)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (231.04, -28.54, -36.80)。achieved target: (53.02, 29.15, -105.84)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (231.87, 29.26, -20.75)。achieved target: (77.98, -41.22, -131.67)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (153.14, -11.27, 48.10)。achieved target: (54.80, -37.90, -118.27)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (169.75, -28.15, 32.44)。achieved target: (30.02, 21.94, -118.47)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (221.85, 9.50, -16.23)。achieved target: (62.44, -21.78, -67.83)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (157.63, -26.80, -10.55)。achieved target: (41.68, 31.50, -103.95)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (225.19, 9.95, -56.29)。achieved target: (32.70, -15.92, -129.83)。expert steps: 0。print, Train, timeout_termination。 steps: 399。target: (194.68, -9.12, 36.25)。achieved target: (38.44, -1.58, -88.16)。expert steps: 0。
#
# print, Train, timeout_termination。 steps: 399。target: (170.90, -12.32, 9.49)。achieved target: (34.50, -9.92, -134.13)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (203.58, 22.15, -22.35)。achieved target: (54.64, -31.28, -113.71)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (175.77, -10.18, -2.67)。achieved target: (30.41, -0.15, -121.52)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (205.89, -6.38, 50.56)。achieved target: (56.60, -26.35, -104.98)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (171.47, 27.91, -59.68)。achieved target: (60.98, -36.80, -145.64)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (240.98, -4.02, -34.45)。achieved target: (31.73, 1.61, -108.57)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (176.12, 27.16, 57.87)。achieved target: (72.75, -43.42, -117.54)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (227.27, -0.58, -27.91)。achieved target: (28.52, -6.21, -117.64)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (231.21, 9.58, 47.84)。achieved target: (47.45, -31.42, -76.19)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (184.88, -8.72, 32.10)。achieved target: (41.16, -11.07, -65.83)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (223.60, -10.85, -42.97)。achieved target: (27.94, 12.72, -139.11)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (229.95, -19.96, 31.40)。achieved target: (35.91, -1.82, -99.13)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (180.86, 24.50, 4.80)。achieved target: (57.40, -35.91, -123.21)。expert steps: 0。print, Train, timeout_termination。 steps: 399。target: (152.21, -24.95, 29.02)。achieved target: (32.23, 9.27, -126.62)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (190.44, 21.77, -4.01)。achieved target: (71.41, -41.75, -127.58)。expert steps: 0。
#
# print, Train, timeout_termination。 steps: 399。target: (215.03, -12.11, -20.32)。achieved target: (30.57, 2.22, -134.86)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (152.47, -25.93, -37.59)。achieved target: (55.23, 84.30, -143.15)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (237.89, -15.91, 30.22)。achieved target: (38.23, -7.95, -58.23)。expert steps: 0。
# print, Train, timeout_termination。 steps: 399。target: (225.49, -13.11, -56.58)。achieved target: (28.78, 30.33, -132.53)。expert steps: 0。
# seed1  ： mean_reward=-213.17 +/- 30.296903826726307
# mean_reward=-213.17 +/- 30.296903826726307 success_rate = 0.004

# %%
def eval(policy_list):
    
    average_reward = 0.0
    average_std = 0.0
    average_successrate = 0.0 
    for index, policy in enumerate(policy_list):
        sac = SAC.load(policy)
        eval_reward, std_reward, eval_success_rate = evaluate_policy_with_success_rate(sac.policy, vec_env, 1000)
        print(f"seed{index+1}  ：",f"mean_reward={eval_reward:.2f} +/- {std_reward}")
        average_reward += eval_reward
        average_std += std_reward
        average_successrate +=eval_success_rate
    return average_reward/len(policy_list),average_std/len(policy_list), average_successrate/len(policy_list)
